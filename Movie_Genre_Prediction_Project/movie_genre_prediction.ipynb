# %% [markdown]
# ## Movie Genre Prediction with TF-IDF

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import pandas as pd
import numpy as np
from scipy.stats import randint
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
from io import StringIO
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_selection import chi2
from IPython.display import display
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
from sklearn import metrics

# %%
df=pd.read_csv('/content/drive/MyDrive/train_data.txt', header=None, names=['id', 'movie_name','genre', 'description'], sep=':::', index_col="id")
# Out:
# <ipython-input-3-794402f1729e>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df=pd.read_csv('/content/drive/MyDrive/train_data.txt', header=None, names=['id', 'movie_name','genre', 'description'], sep=':::', index_col="id")

# %%
df
# Out:
#                                          movie_name          genre  \
# id
# 1                     Oscar et la dame rose (2009)          drama
# 2                                     Cupid (1997)       thriller
# 3                 Young, Wild and Wonderful (1980)          adult
# 4                            The Secret Sin (1915)          drama
# 5                           The Unrecovered (2007)          drama
# ...                                             ...            ...
# 54210                              "Bonino" (1953)         comedy
# 54211                  Dead Girls Don't Cry (????)         horror
# 54212    Ronald Goedemondt: Ze bestaan echt (2008)    documentary
# 54213                     Make Your Own Bed (1944)         comedy
# 54214   Nature's Fury: Storm of the Century (2006)        history
#
#                                              description
# id
# 1       Listening in to a conversation between his do...
# 2       A brother and sister with a past incestuous r...
# 3       As the bus empties the students for their fie...
# 4       To help their unemployed father make ends mee...
# 5       The film's title refers not only to the un-re...
# ...                                                  ...
# 54210   This short-lived NBC live sitcom centered on ...
# 54211   The NEXT Generation of EXPLOITATION. The sist...
# 54212   Ze bestaan echt, is a stand-up comedy about g...
# 54213   Walter and Vivian live in the country and hav...
# 54214   On Labor Day Weekend, 1935, the most intense ...
#
# [54214 rows x 3 columns]

# %% [markdown]
# ### Exploration and Preprocessing

# %%
df.head(2)
# Out:
#                         movie_name       genre  \
# id
# 1    Oscar et la dame rose (2009)       drama
# 2                    Cupid (1997)    thriller
#
#                                           description
# id
# 1    Listening in to a conversation between his do...
# 2    A brother and sister with a past incestuous r...

# %%
df.columns
# Out:
# Index(['movie_name', 'genre', 'description'], dtype='object')

# %% [markdown]
# Let's remove some information that we do not need and build another dataframe that contains "genre" and "description".

# %%
# Create a new dataframe with two columns
df1 = df[['genre', 'description']].copy()

# Remove missing values (NaN)
df1 = df1[pd.notnull(df1['description'])]

df1.shape
# Out:
# (54214, 2)

# %%
# Percentage of descriptions that had text field
total = df1['description'].notnull().sum()
round((total/len(df)*100),1)
# Out:
# 100.0

# %%
pd.DataFrame(df['genre'].unique()).values, len(pd.DataFrame(df['genre'].unique()).values)
# Out:
# (array([[' drama '],
#         [' thriller '],
#         [' adult '],
#         [' documentary '],
#         [' comedy '],
#         [' crime '],
#         [' reality-tv '],
#         [' horror '],
#         [' sport '],
#         [' animation '],
#         [' action '],
#         [' fantasy '],
#         [' short '],
#         [' sci-fi '],
#         [' music '],
#         [' adventure '],
#         [' talk-show '],
#         [' western '],
#         [' family '],
#         [' mystery '],
#         [' history '],
#         [' news '],
#         [' biography '],
#         [' romance '],
#         [' game-show '],
#         [' musical '],
#         [' war ']], dtype=object),
#  27)

# %% [markdown]
# There are 27 different categories that we can use as out target variable. Let us make some changes in categories to avoid potential conflicts.

# %%
# let's work with a smaller smaple of the data to speed things up
df2 = df1.sample(20000, random_state=1).copy()

# %%
# Renaming categories to avoid conflicts
df2['genre'] = df2['genre'].str.strip()

df2.replace({"genre":
          {
                'action': 'action, adventure',
                'adventure': 'action, adventure',
                'war': 'action, adventure',
                'reality-tv': 'entertainment',
                'game-show': 'entertainment',
                'music': 'entertainment',
                'musical': 'entertainment',
                'talk-show': 'entertainment',
                'family': 'family, drama',
                'drama': 'family, drama',
                'adult': 'romance',
                'sci-fi': 'sci-fi fantasy',
                'fantasy': 'sci-fi fantasy',
                'thriller': 'thriller mystery',
                'mystery': 'thriller mystery',
                'news': 'biography, documentary, history, news, crime',
                'crime': 'biography, documentary, history, news, crime',
                'biography': 'biography, documentary, history, news, crime',
                'documentary': 'biography, documentary, history, news, crime',
                'history': 'biography, documentary, history, news, crime',
              }}, inplace=True)

# %%
# Removing conflicting categories (western, short)
condition = (df2['genre'] == 'western') | (df2['genre'] == 'short')

df2 = df2.drop(df2[condition].index)
df2
# Out:
#                                               genre  \
# id
# 10690  biography, documentary, history, news, crime
# 11730                             action, adventure
# 1299   biography, documentary, history, news, crime
# 42665  biography, documentary, history, news, crime
# 40182                                 family, drama
# ...                                             ...
# 21024                                        comedy
# 23049                                 family, drama
# 6783   biography, documentary, history, news, crime
# 35648                                 family, drama
# 6155                                  family, drama
#
#                                              description
# id
# 10690   This documentary film is a heartfelt glimpse ...
# 11730   England Cricket hero Freddie Flintoff spends ...
# 1299    Three gravediggers lovingly maintain the peac...
# 42665   A man, Jean, is critically injured in a freak...
# 40182   Roos and Rana are two friends, who both have ...
# ...                                                  ...
# 21024   Three colleagues (Carol Cheng, Joey Wong, San...
# 23049   Jean, a wealthy young Canadian back from a tr...
# 6783    Journey into Life follows the struggles of th...
# 35648   Back from the war, Marceau Le Guern remembers...
# 6155    A detective is investigating on Andres Carrer...
#
# [17744 rows x 2 columns]

# %%
pd.DataFrame(df2.genre.unique())
df2.genre.value_counts()
# Out:
# family, drama                                   5456
# biography, documentary, history, news, crime    5225
# comedy                                          2707
# entertainment                                    898
# horror                                           813
# action, adventure                                803
# thriller mystery                                 651
# romance                                          491
# sci-fi fantasy                                   380
# animation                                        169
# sport                                            151
# Name: genre, dtype: int64

# %%
fig = plt.figure(figsize=(8,6))
df2.groupby('genre').description.count().sort_values().plot.barh(
    ylim=0, title= 'Descriptions of Movies\n')
plt.xlabel('Number of Comments', fontsize = 10);

# %%
# Create a new column 'category_id' with encoded categories
df2['category_id'] = df2['genre'].factorize()[0]
category_id_df = df2[['genre', 'category_id']].drop_duplicates()


# Dictionaries for future use
category_to_id = dict(category_id_df.values)
id_to_category = dict(category_id_df[['category_id', 'genre']].values)

# New dataframe
df2.head()
# Out:
#                                               genre  \
# id
# 10690  biography, documentary, history, news, crime
# 11730                             action, adventure
# 1299   biography, documentary, history, news, crime
# 42665  biography, documentary, history, news, crime
# 40182                                 family, drama
#
#                                              description  category_id
# id
# 10690   This documentary film is a heartfelt glimpse ...            0
# 11730   England Cricket hero Freddie Flintoff spends ...            1
# 1299    Three gravediggers lovingly maintain the peac...            0
# 42665   A man, Jean, is critically injured in a freak...            0
# 40182   Roos and Rana are two friends, who both have ...            2

# %% [markdown]
# Let us now calculate TF-IDF scores.

# %%
tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5,
                        ngram_range=(1, 2),
                        stop_words='english')

# We transform each description into a vector
features = tfidf.fit_transform(df2.description).toarray()

labels = df2.category_id

print("Each of the %d description is represented by %d features (TF-IDF score of unigrams and bigrams)" %(features.shape))
# Out:
# Each of the 17744 description is represented by 25784 features (TF-IDF score of unigrams and bigrams)

# %%
# Finding the three most correlated terms with each of the genre categories
N = 3
for genre, category_id in sorted(category_to_id.items()):
  features_chi2 = chi2(features, labels == category_id)
  indices = np.argsort(features_chi2[0])
  feature_names = np.array(tfidf.get_feature_names_out())[indices]
  unigrams = [v for v in feature_names if len(v.split(' ')) == 1]
  bigrams = [v for v in feature_names if len(v.split(' ')) == 2]
  print("\n==> %s:" %(genre))
  print("  * Most Correlated Unigrams are: %s" %(', '.join(unigrams[-N:])))
  print("  * Most Correlated Bigrams are: %s" %(', '.join(bigrams[-N:])))
# Out:
# ==> action, adventure:
#   * Most Correlated Unigrams are: operative, martial, bondage
#   * Most Correlated Bigrams are: bound gagged, action adventure, martial arts
#
# ==> animation:
#   * Most Correlated Unigrams are: duck, superhero, animated
#   * Most Correlated Bigrams are: story like, animated movie, whisked away
#
# ==> biography, documentary, history, news, crime:
#   * Most Correlated Unigrams are: film, interviews, documentary
#   * Most Correlated Bigrams are: documentary explores, length documentary, documentary film
#
# ==> comedy:
#   * Most Correlated Unigrams are: sketch, hilarious, comedy
#   * Most Correlated Bigrams are: hilarity ensues, sketch comedy, comedy series
#
# ==> entertainment:
#   * Most Correlated Unigrams are: concert, music, contestants
#   * Most Correlated Bigrams are: live performances, half hour, correct answer
#
# ==> family, drama:
#   * Most Correlated Unigrams are: father, documentary, mother
#   * Most Correlated Bigrams are: young woman, falls love, year old
#
# ==> horror:
#   * Most Correlated Unigrams are: evil, vampire, horror
#   * Most Correlated Bigrams are: group college, college kids, horror film
#
# ==> romance:
#   * Most Correlated Unigrams are: anal, bound, gagged
#   * Most Correlated Bigrams are: securely bound, second story, bound gagged
#
# ==> sci-fi fantasy:
#   * Most Correlated Unigrams are: planet, alien, earth
#   * Most Correlated Bigrams are: human race, sci fi, alien race
#
# ==> sport:
#   * Most Correlated Unigrams are: fifa, workouts, vs
#   * Most Correlated Bigrams are: world championship, tag team, fifa world
#
# ==> thriller mystery:
#   * Most Correlated Unigrams are: murder, killer, thriller
#   * Most Correlated Bigrams are: killer loose, serial killer, psychological thriller

# %% [markdown]
# ### Classification

# %% [markdown]
# We start with a train-test split.

# %%
X = df2['description'] # Collection of documents
y = df2['genre'] # Labels we want to predict

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state = 20)

# %% [markdown]
# Let us train several models, namely,
#
# *   Random Forest
# *   Linear Support Vector Machine
# *   Multinomial Naive Bayes
# *   Logistic Regression

# %%
models = [
    RandomForestClassifier(n_estimators=100, max_depth=5, random_state=0),
    LinearSVC(),
    MultinomialNB(),
    LogisticRegression(random_state=0),
]

# 5 Cross-validation
CV = 5
cv_df = pd.DataFrame(index=range(CV * len(models)))

entries = []
for model in models:
  model_name = model.__class__.__name__
  accuracies = cross_val_score(model, features, labels, scoring='accuracy', cv=CV)
  for fold_idx, accuracy in enumerate(accuracies):
    entries.append((model_name, fold_idx, accuracy))

cv_df = pd.DataFrame(entries, columns=['model_name', 'fold_idx', 'accuracy'])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
mean_accuracy = cv_df.groupby('model_name').accuracy.mean()
std_accuracy = cv_df.groupby('model_name').accuracy.std()

acc = pd.concat([mean_accuracy, std_accuracy], axis= 1, ignore_index=True)
acc.columns = ['Mean Accuracy', 'Standard deviation']
acc
# Out:
#                         Mean Accuracy  Standard deviation
# model_name
# LinearSVC                    0.628607            0.009626
# LogisticRegression           0.620435            0.009953
# MultinomialNB                0.535054            0.004908
# RandomForestClassifier       0.499492            0.005616

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='model_name', y='accuracy',
            data=cv_df,
            color='lightblue',
            showmeans=True)
plt.title("MEAN ACCURACY (cv = 5)\n", size=14);

# %% [markdown]
# Evaluation

# %%
X_train, X_test, y_train, y_test,indices_train,indices_test = train_test_split(features, labels, df2.index, test_size=0.25, random_state=1)

model = LinearSVC()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
# Classification report
print('\t\t\t\tCLASSIFICATIION METRICS\n')
print(metrics.classification_report(y_test, y_pred, target_names= df2['genre'].unique()))
# Out:
# 				CLASSIFICATIION METRICS
#
#                                               precision    recall  f1-score   support
#
# biography, documentary, history, news, crime       0.72      0.84      0.77      1329
#                            action, adventure       0.39      0.22      0.28       193
#                                family, drama       0.61      0.73      0.67      1369
#                                       comedy       0.53      0.56      0.54       663
#                             thriller mystery       0.42      0.13      0.20       172
#                                entertainment       0.62      0.31      0.41       235
#                                      romance       0.62      0.20      0.30       121
#                                       horror       0.68      0.60      0.64       192
#                                    animation       0.33      0.03      0.05        36
#                               sci-fi fantasy       0.48      0.24      0.32        89
#                                        sport       0.75      0.32      0.45        37
#
#                                     accuracy                           0.63      4436
#                                    macro avg       0.56      0.38      0.42      4436
#                                 weighted avg       0.61      0.63      0.61      4436

# %% [markdown]
# Confusion Matrix

# %%
conf_mat = confusion_matrix(y_test, y_pred)
fig, ax = plt.subplots(figsize=(8,8))
sns.heatmap(conf_mat, annot=True, cmap="Blues", fmt='d', xticklabels=category_id_df.genre.values, yticklabels=category_id_df.genre.values)

plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title("CONFUSION MATRIX - LinearSVC\n", size=16);

# %% [markdown]
# ### Analysing Results

# %% [markdown]
# Let’s have a look at the texts that were wrongly classified.

# %%
for predicted in category_id_df.category_id:
  for actual in category_id_df.category_id:
    if predicted != actual and conf_mat[actual, predicted] >= 20:
      print("'{}' predicted as '{}' : {} examples.".format(id_to_category[actual],
                                                           id_to_category[predicted],
                                                           conf_mat[actual, predicted]))

      display(df2.loc[indices_test[(y_test == actual) & (y_pred == predicted)]][['genre',
                                                                'description']])
      print('')
# Out:
# 'action, adventure' predicted as 'biography, documentary, history, news, crime' : 43 examples.
#                    genre                                        description
# id
# 53224  action, adventure   Mars, 2044. The UN establishes MARSCORP (Mart...
# 39452  action, adventure   Writen by award winning filmmaker Damian Perk...
# 30765  action, adventure   James and John are working in the Commercial ...
# 26040  action, adventure   Starostin brothers are the sons of a legendar...
# 3678   action, adventure   The three-season series Poyraz Karayel will f...
# 14118  action, adventure   Johnny Weissmuller guides Professor Blakely a...
# 44445  action, adventure   Croc Labyrinth Brad and Vince have succeeded ...
# 17625  action, adventure   An expedition into the interior of Papua New ...
# 22694  action, adventure   There is nothing fair, honorable, or just abo...
# 28476  action, adventure   Russian and American Navy are working togethe...
# 16586  action, adventure   A man is chosen to deliver a princess and a d...
# 44628  action, adventure   A group of young cineastes. Their dream to ma...
# 25423  action, adventure   Jasper Penny, 80's, was there when William Ro...
# 671    action, adventure   Treasure Hunters (Arabic: Mustakshiful Kunooz...
# 43398  action, adventure   A Swedish motorcycle club becomes prospects t...
# 44348  action, adventure   Oshota Funakoshi is not just your everyday pl...
# 42331  action, adventure   Afghanistan, 2009. A Rifle section is halfway...
# 41663  action, adventure   John Cena: My Life highlights the spectacular...
# 6314   action, adventure   When, in 1914, Shackleton's ship The Enduranc...
# 28388  action, adventure   Guilt ridden by the abduction and murder of h...
# 32090  action, adventure   Malachi Radixx (Wiliam Lee) is a former cover...
# 20580  action, adventure   Edurne Pasaban, the first woman to ascend the...
# 14209  action, adventure   Cleo, a research chemist, accidentally create...
# 45445  action, adventure   Brick Bardo is on a mission to find out which...
# 29029  action, adventure   Agnee 2 is a 2015 Bangladeshi action film dir...
# 2922   action, adventure   RETALIATION...a movie that uncovers the perce...
# 51026  action, adventure   America mining engineers seek to gain the min...
# 40546  action, adventure   While super-hero movies are the sensation of ...
# 18119  action, adventure   One mans fight for revenge to take down the m...
# 41759  action, adventure   A "reality show" that presented stories of re...
# 36611  action, adventure   Who or what is killing rhinos in the Hluhluwe...
# 30023  action, adventure   Journalist and avid adventure traveler, Kinga...
# 47335  action, adventure   Kamal comes forward to represent Vasanthi's g...
# 32422  action, adventure   Roar of the Wild is an interactive wild adven...
# 30734  action, adventure   Memory of the victims of the Kragujevac massa...
# 49322  action, adventure   Through a 16mm projector and cans of film inh...
# 2794   action, adventure   A young man from the banks of the Ibar River ...
# 45982  action, adventure   Two aspiring Documentarians travel west and m...
# 9659   action, adventure   This game is a spin-off of the film Ice Age: ...
# 28482  action, adventure   6,000 years ago, in the land where The Empero...
# 16779  action, adventure   Late in the 21st century a 5 year bloody war ...
# 21884  action, adventure   A million years ago in Africa: the last of th...
# 47105  action, adventure   The film is set in the 60s of the 20th centur...
# 'family, drama' predicted as 'biography, documentary, history, news, crime' : 156 examples.
#                genre                                        description
# id
# 34444  family, drama   Kaori is pursuing her career as a journalist ...
# 41124  family, drama   The film shows an obscure episode from the li...
# 20369  family, drama   It is a futuristic story, which takes place i...
# 21769  family, drama   "The Forgotten Four: Immortality" acts as a b...
# 21915  family, drama   Latest example of Spanish "neokinki" cinema, ...
# ...              ...                                                ...
# 25275  family, drama   Shake is a powerful shaman of the Yanomami pe...
# 2546   family, drama   The silent film "Gypsy Girl in the Bedroom"(1...
# 39438  family, drama   A young extraterrestrial woman undergoing cos...
# 12323  family, drama   One year after the collapse of civilization a...
# 11941  family, drama   The Zenith Electronics Corporation presented ...
#
# [156 rows x 2 columns]
# 'comedy' predicted as 'biography, documentary, history, news, crime' : 69 examples.
#         genre                                        description
# id
# 36128  comedy   Tthe film is based on the concept of "New Ame...
# 51751  comedy   Funhaus is a YouTube gaming channel working u...
# 5734   comedy   Dwight Serrento, once a pop-icon is now reduc...
# 35172  comedy   Rudy is an American of Mexican descent who is...
# 28557  comedy   iBox is a bilingual, humoristic and provocati...
# ...       ...                                                ...
# 7675   comedy   Lab technician Virgil Gurdies embarks on an e...
# 38016  comedy   Like many who grew up in the 1980s, John Tavi...
# 8934   comedy   "Relatively Well" follows Dave's journey to s...
# 2423   sci-fi fantasy   Dillon stumbles on a little known news story ...
# 11529  sci-fi fantasy   Union, 2445: To end crime and disease, citize...
# 44894  sci-fi fantasy   "The apparent size and age of the universe su...
# 823    sci-fi fantasy   "Five Crowns" is the culmination of the "Dest...
# 20444  sci-fi fantasy   STARHUNTER Transformation, continues the adve...
# 26034  sci-fi fantasy   Some time in the distant future, Earth's natu...
# 16612  sci-fi fantasy   Innovative anthology series was one of the fi...
# 46750  sci-fi fantasy   After a hacker-inspired civil war devastates ...
# 3553   sci-fi fantasy   Take Everything is a movie series which gives...
# 15761  sci-fi fantasy   50 years into the future, time travel is inve...
# 10979  sci-fi fantasy   Leading magicians perform tricks and escape f...
# 'family, drama' predicted as 'action, adventure' : 21 examples.
#                genre                                        description
# id
# 918    family, drama   An unauthorised remake of Hitchcock's classic...
# 20767  family, drama   25 years after fleeing Cambodia for the Phili...
# 23574  family, drama   In upscale Opulent, Arizona, Edward Pierce, m...
# 22218  family, drama   A pre-World War II saber-rattler that finds a...
# 17006  family, drama   Set in the closed and poisonous world of an i...
# 36364  family, drama   In the future (1921), an alliance of several ...
# 4901   family, drama   Fourteen years ago, Wai Yat Ming (Ti Lung) we...
# 41191  family, drama   In 18th-Century Russia, the Czar, Paul, is su...
# 3026   family, drama   The Story is about a boy named Premji (played...
# 6889   family, drama   Patriot Yun Bong-chang attempts to assassinat...
# 36914  family, drama   The Twelve followers of Jesus assemble in an ...
# 49486  family, drama   The film is set during 1962 in Sevastopol, Cr...
# 42245  family, drama   The hilarious highlight of John Boorman's HOP...
# 35791  family, drama   1922:Irish Revolution.Catherine, a servant in...
# 15422  family, drama   Huge collection of the best non-stop model ra...
# 18870  family, drama   The story of the film is based on a law colle...
# 45901  family, drama   Arranged by a smuggling syndicate, A-Hong and...
# 47308  family, drama   Cassie Holland is a tough and feisty former p...
# 44602  family, drama   The theatre company managed by Marco is passi...
# 723    family, drama   Police constables Balagopal (Sreejith Ravi) a...
# 25859  family, drama   When they are left on their own a few days be...
# 'biography, documentary, history, news, crime' predicted as 'family, drama' : 153 examples.
#                                               genre  \
# id
# 38162  biography, documentary, history, news, crime
# 21048  biography, documentary, history, news, crime
# 35772  biography, documentary, history, news, crime
# 31261  biography, documentary, history, news, crime
# 47948  biography, documentary, history, news, crime
# ...                                             ...
# 40342  biography, documentary, history, news, crime
# 27850  biography, documentary, history, news, crime
# 44952  biography, documentary, history, news, crime
# 49418  biography, documentary, history, news, crime
# 10870  biography, documentary, history, news, crime
#
#                                              description
# id
# 38162   Following the world's youngest transsexual as...
# 21048   In the aftermath of the fatal Airbus A320 acc...
# 35772   Afrikaner Juan van Tonder, bon vivant of Cape...
# 31261   Two people fall in love even though the conve...
# 47948   Miguel de Uamuno, a Spanish writer and philos...
# ...                                                  ...
# 40342   Castmembers from the highly popular MTV serie...
# 27850   Corruption has eaten away at the hearts of tw...
# 44952   After A Suicide - Moving Past Why tells the s...
# 49418   Pai is a film about taking one's own path in ...
# 10870   Beginning in 2011, the story of UNC's "fake c...
#
# [153 rows x 2 columns]
# 'action, adventure' predicted as 'family, drama' : 56 examples.
#                    genre                                        description
# id
# 40881  action, adventure   This urban drama is based on a shocking true ...
# 28844  action, adventure   ACTION/THRILLER Red is the color that we pay ...
# 51756  action, adventure   A beautiful con-woman claims to be Kelsie's l...
# 11271  action, adventure   A young kenpo karate martial artist returns h...
# 36386  action, adventure   A female police rookie wants to remain partne...
# 25     action, adventure   Dong-woo is released from prison after a shor...
# 32100  action, adventure   Arun (Rajinikanth) is the haughty and bellige...
# 16627  action, adventure   The story begins with a man Arjun(mithun) wor...
# 16720  action, adventure   North Korean spy Jang Duk begins to have his ...
# 23889  action, adventure   Jordan Parker is a wife first and a mother of...
# 1767   action, adventure   Deputy Commissioner of Police single-handedly...
# 20715  action, adventure   Williams is the old town boss, though his pow...
# 8070   action, adventure   The Secretary of the Navy orders the U.S.S. U...
# 10420  action, adventure   A young Canadian fighter pilot is sent to joi...
# 48829  action, adventure   In the midst of Texas storm season, a cold-bl...
# 52737  action, adventure   Travis Winslow is an honest man trapped in th...
# 15951  action, adventure   Danny Krueger is a twenty-year old street rac...
# 20260  action, adventure   Five unrelated tales: (1) "The Ravishing Quee...
# 45639  action, adventure   Placed on a company's board of directors as a...
# 11014  action, adventure   In the ancient dynasty time, the draft dancin...
# 5192   action, adventure   Fire Truck Video for toddlers and kids, see h...
# 30638  action, adventure   He's lost his memory, but not his skill: Afte...
# 23368  action, adventure   Police Inspector Ram takes over charge of a p...
# 41748  action, adventure   The story tells about Jack, a martial artist ...
# 812    action, adventure   Fearing he will become a government informant...
# 50381  action, adventure   Lt. Bertelli visits Saly Beckett, a blind gir...
# 40853  action, adventure   An irresponsible preppie, Preston West, is pr...
# 38844  action, adventure   Tycoon, Tang Shih Hai, rules most of the busi...
# 3181   action, adventure   Gemini Rue is a cyberpunk graphic adventure g...
# 50536  action, adventure   In the autumn of 1991, a small group of Croat...
# 28546  action, adventure   A railroad employee finds out the identity of...
# 37371  action, adventure   Squad with new characters with Courtney 357 f...
# 3161   action, adventure   A young girl is kidnapped and thrown in the e...
# 6711   action, adventure   After the death of his wife, wealthy Mr. Verm...
# 6948   action, adventure   There are two paths in the world you can choo...
# 41690  action, adventure   A cop copes with several personal and profess...
# 20941  action, adventure   Widowed by the sudden passing of his wife, Su...
# 517    action, adventure   Rammohan lives a poor lifestyle in India alon...
# 53794  action, adventure   When a man wakes up in the back of his SUV as...
# 27933  action, adventure   Years after Alaskan storekeeper Gale had resc...
# 10367  action, adventure   Live the life of a sim wondering the streets ...
# 51958  action, adventure   This is an Amazon Studios test movie, a rough...
# 14423  action, adventure   Ringo and Freddie, two 16 year teenagers from...
# 44141  action, adventure   A man wrongly imprisoned for murder breaks ou...
# 11247  action, adventure   While the novelist Sami Akl is finalizing his...
# 5581   action, adventure   Whenever evil surfaces, Lord Krishna will be ...
# 17747  action, adventure   Alberto is an Italian driver who works as a p...
# 3297   action, adventure   The servant Juarez kills his boss to marry hi...
# 44987  action, adventure   A typical Sam Katzman sand-and-sandals saga t...
# 42604  action, adventure   Veteran hitman Jake Lead has second thoughts ...
# 15103  action, adventure   A writer for writing material, search to an a...
# 36444  action, adventure   Urbanito Dizon or Nitoy to his friends was br...
# 33132  action, adventure   Park Ho, a South Korean secret agent statione...
# 38288  action, adventure   Set in present day, a senator with a controve...
# 23818  action, adventure   Temujin, who later became Genghis Khan is wis...
# 25246  action, adventure   The inhabitants of Vienna line the streets to...
# 'comedy' predicted as 'family, drama' : 187 examples.
#         genre                                        description
# id
# 18013  comedy   This is love stories of different generations...
# 2089   comedy   Primitive, cowardly, greedy and fame seeking ...
# 14634  comedy   The most important celluloid in all of animat...
# 3279   comedy   Garage Daze is the story of a former high sch...
# 3806   comedy   Kaat leaves Max the day after her thirtieth b...
# ...       ...                                                ...
# 5987   comedy   Three young housewives, feeling neglected and...
# 29155  comedy   Text " Plot Edit Jimmy (Jimmy Sharma) and Roc...
# 14159  comedy   Pluto can't help himself. Adopting the roles ...
# 4085   comedy   A clerk falls in love with a beautiful dancer...
# 1588   comedy   Robinson Crusoe and Cuma, who celebrate the 1...
#
# [187 rows x 2 columns]
# 'thriller mystery' predicted as 'family, drama' : 75 examples.
#                   genre                                        description
# id
# 22759  thriller mystery   Sarah Mitchell, a loyal and loving young wife...
# 536    thriller mystery   In the children's ward of St Luke's Hospital,...
# 42268  thriller mystery   Through the redemption of a former torturer o...
# 6779   thriller mystery   High school student Juri leaps to her death. ...
# 26077  thriller mystery   After narrowly avoiding death in a tragic acc...
# ...                 ...                                                ...
# 50831  thriller mystery   In a bustling Tel Aviv, a man suffering from ...
# 53804  thriller mystery   A shocking tale of young innocence facing a s...
# 25705  thriller mystery   Shubhada is hit by Dr Ajinkiya Vartak's car a...
# 16180  thriller mystery   Mark, a disturbed young man, harbors sexual d...
# 12114  thriller mystery   Acclaimed underground filmmaker Pete Anderson...
#
# [75 rows x 2 columns]
# 'entertainment' predicted as 'family, drama' : 33 examples.
#                genre                                        description
# id
# 23335  entertainment   "Lapsed Catholics", once upon a time the bigg...
# 33805  entertainment   We all have it. A junk drawer, a messy closet...
# 51627  entertainment   S4K's Romeo & Juliet is set in Verona and tel...
# 40012  entertainment   The Earl of Essex, Robert Devereux, is hot-bl...
# 3005   entertainment   "The Tony Fontane Story" is a dramatization o...
# 50131  entertainment   GIVE ME SHELTER takes the perennially success...
# 51215  entertainment   Like a favorite aunt who comes calling when y...
# 11180  entertainment   The film's plot follows a young girl who is a...
# 6666   entertainment   Macushlah was raised by Father O'Flynn after ...
# 51390  entertainment   Tribble Reese has decided to give love anothe...
# 21473  entertainment   Amy is a model and admitted diva enjoying the...
# 32151  entertainment   In the Los Laureles farmhouse, owned by don J...
# 943    entertainment   Paster Ruford Royal is more like a hustler th...
# 32622  entertainment   In Long Beach, California, school bus driver ...
# 30498  horror   Due to financial problems, Yilmaz family move...
# 31015  horror   A teenage boy goes back to his hometown in So...
# 54043  horror   Out of boredom, three girls play with an inhe...
# 5931   horror   When Etain wakes up on a Scottish island with...
# 38517  horror   Kelby Unger is a young man from a dysfunction...
# 48792  horror   The film follows the story of Elliot, who awa...
# 'sci-fi fantasy' predicted as 'family, drama' : 23 examples.
#                 genre                                        description
# id
# 6013   sci-fi fantasy   Amber and friends follow her sister Senna int...
# 12453  sci-fi fantasy   Dr. Jin, the top surgeon in Korea in the 21st...
# 47244  sci-fi fantasy   Akash is lonely real estate agent who uses vi...
# 45205  sci-fi fantasy   Frankie in Blunderland tells the story of Fra...
# 29868  sci-fi fantasy   John Carson is a worldly man of means. Living...
# 50332  sci-fi fantasy   Community-oriented film project following som...
# 8147   sci-fi fantasy   A religious guy find himself facing his demon...
# 5721   sci-fi fantasy   When an old key is left to a young woman by h...
# 1805   sci-fi fantasy   The Boy on the Bus is a magical realism fable...
# 8037   sci-fi fantasy   In a future society where soft drinks are onl...
# 38655  sci-fi fantasy   The strange disappearance of a young woman in...
# 38773  sci-fi fantasy   The story begins with Reden Caharian, a lovin...
# 20072  sci-fi fantasy   An all new revised take on the time honoured ...
# 38900  sci-fi fantasy   Dr. Grood has succeeded in winning control ov...
# 32987  sci-fi fantasy   A young innkeeper's peaceful days suddenly be...
# 46689  sci-fi fantasy   In the quiet town of Maple Grove, Pennsylvani...
# 2064   sci-fi fantasy   A glowing space ship that arrives in the midd...
# 45840  sci-fi fantasy   This show is a sequel to the Disney movie "De...
# 27279  sci-fi fantasy   Enchanted Garden is set against the entrancin...
# 34843  sci-fi fantasy   Aboard the R/V Triton, the Project Neptune te...
# 40694  sci-fi fantasy   Seventeen year old Bulgarian boy, Orlin Nedko...
# 20788  sci-fi fantasy   In 2075, the country is destroyed by America'...
# 49462  sci-fi fantasy   Inspired by NBC's drama 'Heroes', 'Zodiac' is...
# 'biography, documentary, history, news, crime' predicted as 'comedy' : 24 examples.
#                                               genre  \
# id
# 23952  biography, documentary, history, news, crime
# 18952  biography, documentary, history, news, crime
# 287    biography, documentary, history, news, crime
# 15942  biography, documentary, history, news, crime
# 20880  biography, documentary, history, news, crime
# 31920  biography, documentary, history, news, crime
# 21624  biography, documentary, history, news, crime
# 10858  biography, documentary, history, news, crime
# 42543  biography, documentary, history, news, crime
# 22997  biography, documentary, history, news, crime
# 23047  biography, documentary, history, news, crime
# 25971  biography, documentary, history, news, crime
# 26853  biography, documentary, history, news, crime
# 31852  biography, documentary, history, news, crime
# 15014  biography, documentary, history, news, crime
# 11604  biography, documentary, history, news, crime
# 15107  biography, documentary, history, news, crime
# 5629   biography, documentary, history, news, crime
# 50014  biography, documentary, history, news, crime
# 25116  biography, documentary, history, news, crime
# 19273  biography, documentary, history, news, crime
# 24796  biography, documentary, history, news, crime
# 15670  biography, documentary, history, news, crime
# 52844  biography, documentary, history, news, crime
#
#                                              description
# id
# 23952   Jonathan Rendall's broke, he's been given Ł12...
# 18952   November 12, the Lindbergh couple alighted in...
# 287     On his first burglary, a locksmith finds hims...
# 15942   One summer in S&M and leather. Chicago, New Y...
# 20880   Hired by a surveillance company to oversee th...
# 31920   A story about four neighborhood boys who like...
# 21624   "New York vs Los Angeles" pits the two very d...
# 10858   Naina is driven by the motto "Shoot for the m...
# 42543   Paolo Virno is one of today's most influentia...
# 22997   'Hannah Wolfe' struggles to make ends meet. T...
# 23047   February 1978. After several months of hard w...
# 25971   "Homeless '99" exposes a day in the life of a...
# 26853   Director John Webster convinces his wife and ...
# 31852   A visionary unlike anyone else and narrated f...
# 15014   A filmmaker sets out make a film sbout her Ti...
# 11604   Petr was an urban man from a block of flats i...
# 15107   Born into the legacy of blue collar workers, ...
# 5629    Three Yugoslav partners-in-crime connect in A...
# 50014   An Iranian filmmaker wants to move to Germany...
# 25116   LAND GRAB is the story of an eccentric financ...
# 19273   Playboy Video Magazine was literally a video ...
# 24796   "THE KINGDOM OF ZYDECO is both a cunning litt...
# 15670   Mail <svaradi@sprynet.com> for translation. S...
# 52844   Fasty, who comes back to the Crazy Horse afte...
# 'action, adventure' predicted as 'comedy' : 21 examples.
#                    genre                                        description
# id
# 52954  action, adventure   Cleo inherits an adult bookstore, but her unc...
# 52851  action, adventure   Young heiress Helen Stuart is engaged to Mont...
# 5223   action, adventure   Carly Banks, a movie actress desperate for wo...
# 47484  action, adventure   The war veteran Jim (Reed Howes) is an airpla...
# 44544  action, adventure   It's been one year since the "Overachievers" ...
# 5529   action, adventure   Windup is a very original comedy. We follow B...
# 44791  action, adventure   IT IS A STORY OF A BOY SACHIN WHO IS VERY KIN...
# 5911   action, adventure   Late in World War II, an inexperienced U.S. o...
# 18348  action, adventure   There's trouble at the local television stati...
# 33438  action, adventure   Max hunts and eliminates rogue agents and unt...
# 51831  action, adventure   This short lived superhero show was about a C...
# 5308   action, adventure   Stephanie Edgley is a twelve-year old girl li...
# 13103  action, adventure   Zak O'Brien is an animal trainer for the popu...
# 27579  action, adventure   Nora is a stewardess for ATI Airlines. She la...
# 7623   action, adventure   Mary Paz is a strong-willed woman who always ...
# 46919  action, adventure   A former British Naval Officer now makes his ...
# 33437  action, adventure   Soldier of fortune Ken Conway gets a job offe...
# 52586  action, adventure   ACTION/THRILLER. Filmed in Michigan. A corrup...
# 291    action, adventure   Four fearless and intrepid girls get selected...
# 37147  action, adventure   Set in the 19th century, strong believers of ...
# 10591  action, adventure   A drug lord in New York, named Damian, has cr...
# 'family, drama' predicted as 'comedy' : 154 examples.
#                genre                                        description
# id
# 2301   family, drama   Be the Church centers around the life of a 20...
# 21297  family, drama   Terry Willis grew up like many youths with dr...
# 3827   family, drama   It's a based of members from a youtube channe...
# 25522  family, drama   Alex Calder (Julia Denton Frances), a journal...
# 5453   family, drama   A movie director is approached by his old mat...
# ...              ...                                                ...
# 13043  family, drama   Rides is a British television series produced...
# 5511   entertainment   Twenty-eight year old Jeannie MacLean has led...
# 26513  entertainment   Adults compete in a gladiatorial arena fore t...
# 30675  entertainment   Two Greek celebrities carry out pranks on clu...
# 26647  entertainment   Announcers roamed through the audience for th...
# 26635  entertainment   It's hard to catch a break in Boston--especia...
# 38893  entertainment   A slapstick horror musical fairytale about lo...
# 30113  entertainment   In every episode, four house-proud home owner...
# 14661  entertainment   From Streamy Award nominated director, Scott ...
# 37780  entertainment   A resident is sitting on a functioning toilet...
# 11865  entertainment   Vacation Challenge is a new show produced by ...
# 15541  entertainment   Recently single after being married for (what...
# 52480  entertainment   It is rare when four of the Bolshoi's greates...
# 36550  entertainment   Bonus DVD featuring four video clips ('Stupid...
# 44404  entertainment   Direct from London's glittering West End, our...
# 'romance' predicted as 'comedy' : 33 examples.
#          genre                                        description
# id
# 23875  romance   A comedy about Ted, feeling trapped in his ma...
# 53414  romance   Filmed on location in the crystal waters of t...
# 29577  romance   A small-town girl goes to New York hoping to ...
# 39857  romance   An advertising executive, Senthil (Cheran) ta...
# 26617  romance   Billy works as a maintenance guy in a luxury ...
# 10245  romance   The headmaster of a small British public scho...
# 42376  romance   Charmane Star is a beautiful Asian actress st...
# 30225  romance   Shurik is a talented designer, but like every...
# 27885  romance   Arsala comes to her home, as she thinks her p...
# 18549  romance   Girls will be girls and what they are is horn...
# 50615  romance   This romantic comedy is intended to portray t...
# 21224  romance   Hog-mouth`s daily life consist of weed, lazin...
# 17677  romance   Spike arrives in Sydney, Australia, only to l...
# 23106  romance   Nina is a porn star. Sharon is a secretary wh...
# 11862  romance   "STAN MANN" (STEVEN CHASE), a new money, mult...
# 21887  romance   A beautiful woman and good looking man are ha...
# 18973  romance   The sign on the door reads Sexual Therapist -...
# 7169   romance   Café Memoria is a new restaurant in town, hop...
# 30037  romance   After a hot and heavy coupling with her ex-bo...
# 25561  romance   Sung-ju enlists in the army after failing to ...
# 7596   romance   Claudio is businessman who has various sexual...
# 28836  romance   The game of Cowboys and Indians takes on a ne...
# 26130  romance   Sweetheart's award winning series brings up t...
# 24566  romance   Jo Biwi Se Kare Pyaar is a romantic-comedy ab...
# 15776  romance   Katherine Mitchell (Linda Thorson), a widowed...
# 21567  romance   You too can find true love. Just ask the thou...
# 22102  romance   Two stories run simultaneously: two young wom...
# 21847  romance   Art Gallery owner Rachel Ryan uses her ample ...
# 558    romance   When a sex contest is held in Chicago, the be...
# 25459  romance   A killer fails to assassinate his target and ...
# 16503  romance   Kasimir Glück's sex life is restricted to onc...
# 26663  romance   Millie and Suzie are two close female friends...
# 47652  romance   Pulkesh is a normal man who is smiling charac...

# %% [markdown]
# Most correlated terms with each category¶

# %%
model.fit(features, labels)

N = 4
for Product, category_id in sorted(category_to_id.items()):
  indices = np.argsort(model.coef_[category_id])
  feature_names = np.array(tfidf.get_feature_names_out())[indices]
  unigrams = [v for v in reversed(feature_names) if len(v.split(' ')) == 1][:N]
  bigrams = [v for v in reversed(feature_names) if len(v.split(' ')) == 2][:N]
  print("\n==> '{}':".format(Product))
  print("  * Top unigrams: %s" %(', '.join(unigrams)))
  print("  * Top bigrams: %s" %(', '.join(bigrams)))
# Out:
# ==> 'action, adventure':
#   * Top unigrams: adventure, bondage, wwf, platoon
#   * Top bigrams: action adventure, martial arts, desert island, bad guys
#
# ==> 'animation':
#   * Top unigrams: animated, adventures, duck, superhero
#   * Top bigrams: time travel, man man, story like, whisked away
#
# ==> 'biography, documentary, history, news, crime':
#   * Top unigrams: documentary, interviews, portrait, reveal
#   * Top bigrams: make film, 60 years, real story, story friendship
#
# ==> 'comedy':
#   * Top unigrams: comedy, hilarious, mockumentary, misadventures
#   * Top bigrams: best friends, married woman, york city, film crew
#
# ==> 'entertainment':
#   * Top unigrams: contestants, musical, songs, hosted
#   * Top bigrams: reality series, music video, young people, romeo juliet
#
# ==> 'family, drama':
#   * Top unigrams: drama, tokyo, based, drifter
#   * Top bigrams: feature film, wedding night, black comedy, woman life
#
# ==> 'horror':
#   * Top unigrams: horror, vampire, evil, zombies
#   * Top bigrams: horror film, years ago, murderous rampage, college kids
#
# ==> 'romance':
#   * Top unigrams: sex, gagged, anal, orgy
#   * Top bigrams: love wants, childhood friends, love wife, discovers true
#
# ==> 'sci-fi fantasy':
#   * Top unigrams: earth, mankind, wizard, space
#   * Top bigrams: alien race, wrong hands, stop evil, time travel
#
# ==> 'sport':
#   * Top unigrams: vs, tournament, ufc, match
#   * Top bigrams: fifa world, world championship, world series, doesn just
#
# ==> 'thriller mystery':
#   * Top unigrams: thriller, murder, murdered, revolves
#   * Top bigrams: psychological thriller, mysterious man, mysterious woman, mysterious person

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state = 0)

tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5, ngram_range=(1, 2), stop_words='english')

fitted_vectorizer = tfidf.fit(X_train)
tfidf_vectorizer_vectors = fitted_vectorizer.transform(X_train)

model = LinearSVC().fit(tfidf_vectorizer_vectors, y_train)

# %% [markdown]
# Let's come up with a new descriptions and see how our model does.

# %% [markdown]
# **1. Whisper of the Heart**
#
# * **Genre**: Romance, Animation

# %%
new_description = """Hey, just watched "Whisper of the Heart" and it's awesome! It's a sweet coming-of-age story about a girl finding her passion for writing. Loved the relatable characters and the beautiful animation. Only downside, I wish there was more of the fantasy element hinted in the beginning. Overall, a heartwarming flick!"""
print(model.predict(fitted_vectorizer.transform([new_description])))
# Out:
# ['family, drama']

# %% [markdown]
# **2. The Conjuring: The Devil Made Me Do It.**
#
# * **Genre**: Horror

# %%
new_description = """Hey, just watched "The Conjuring: The Devil Made Me Do It." It was super scary with lots of intense moments that kept me on the edge of my seat. Loved how they mixed horror with a detective vibe. Only downside, some scenes felt a bit rushed, but overall, a solid spooky time!"""
print(model.predict(fitted_vectorizer.transform([new_description])))
# Out:
# ['horror']

# %% [markdown]
# **3. Jurassic World**
#
# * **Genre**: Action, Adventure

# %%
new_description = """Jurassic World was a wild ride! The dinosaurs were jaw-dropping, and the excitement never let up. I loved the action, but some moments were a bit cheesy, and the story was kinda predictable. Overall, though, it's a thrilling watch!"""
print(model.predict(fitted_vectorizer.transform([new_description])))
# Out:
# ['action, adventure']
